# %% [markdown]
# # linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
x=np.array([6.5,6.8,7.0,8.0,8.5,9.8,10.5,5.5,5.0])
x_=np.mean(x)
y=np.array([180,195,210,235,280,350,400,170,160])
y_=np.mean(y)

# %%
plt.scatter(x,y)

# %%
slope=np.sum((x-x_)*(y-y_))/np.sum((x-x_)**2)

# %%
slope
# Out:
# 44.20003228931224

# %%
np.cov(x,y,ddof=1)/np.var(x,ddof=1)
# Out:
# array([[1.00000000e+00, 4.42000323e+01],
#        [4.42000323e+01, 2.07438650e+03]])

# %%
intercept=y_-slope*(x_)
intercept
# Out:
# -89.76913141750077

# %%
ypred=intercept+slope*(x)

# %%
ypred
# Out:
# array([197.53107846, 210.79108815, 219.63109461, 263.8311269 ,
#        285.93114304, 343.39118502, 374.33120762, 153.33104617,
#        131.23103003])

# %%
y
# Out:
# array([180, 195, 210, 235, 280, 350, 400, 170, 160])

# %%
plt.plot(y,ypred,"*")

# %%
np.sum((y-ypred))
# Out:
# -4.831690603168681e-13

# %%
from sklearn.linear_model import LinearRegression

# %%
X=pd.DataFrame(x)

# %%
#inbuiltr mmodel approach
model=LinearRegression()
model.fit(X,y)
model.predict(X)
# Out:
# array([197.53107846, 210.79108815, 219.63109461, 263.8311269 ,
#        285.93114304, 343.39118502, 374.33120762, 153.33104617,
#        131.23103003])

# %%
ypred #  formula approach
# Out:
# array([197.53107846, 210.79108815, 219.63109461, 263.8311269 ,
#        285.93114304, 343.39118502, 374.33120762, 153.33104617,
#        131.23103003])

# %%
model.coef_
# Out:
# array([44.20003229])

# %%
model.intercept_
# Out:
# -89.76913141750077

# %%
plt.plot(x,y,'*')
plt.plot(x,ypred,'o-')

# %%
X1=pd.DataFrame([7.5])

# %%
model.predict(X1)
# Out:
# array([241.73111075])

# %%
import statsmodels.formula.api as smf

# %%
A=pd.DataFrame({'bmi':[6.5,6.8,7.0,8.0,8.5,9.8,10.5,5.5,5.0],'glu':[180,195,210,235,280,350,400,170,160]})

# %%
statmoddel=smf.ols('glu~bmi',A).fit()

# %%
yypred=statmoddel.predict(A['bmi'])

# %%
statmoddel.params
# Out:
# Intercept   -89.769131
# bmi          44.200032
# dtype: float64

# %%
statmoddel.summary()
# Out:
# C:\Users\shaik khaja vali\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    glu   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     113.3
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           1.42e-05
# Time:                        12:46:43   Log-Likelihood:                -39.373
# No. Observations:                   9   AIC:                             82.75
# Df Residuals:                       7   BIC:                             83.14
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -89.7691     32.030     -2.803      0.026    -165.507     -14.031
# bmi           44.2000      4.153     10.642      0.000      34.379      54.021
# ==============================================================================
# Omnibus:                        1.342   Durbin-Watson:                   0.506
# Prob(Omnibus):                  0.511   Jarque-Bera (JB):                0.705
# Skew:                           0.176   Prob(JB):                        0.703
# Kurtosis:                       1.675   Cond. No.                         34.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.plot(y,ypred,'*')

# %%
cor=np.corrcoef(y,ypred)
cor
# Out:
# array([[1.        , 0.97046024],
#        [0.97046024, 1.        ]])

# %% [markdown]
# # R2

# %%
cor*cor
# Out:
# array([[1.        , 0.94179308],
#        [0.94179308, 1.        ]])

# %%
sse=sum((y-ypred)**2)
sse
# Out:
# 3323.9384888601876

# %%
var=sum((y-np.mean(y))**2)
var
# Out:
# 57105.55555555555

# %%
1-(sse/var)
# Out:
# 0.9417930802612283

# %%
Data=pd.read_csv('car-mpg (1).csv')

# %%
Data.describe().T
# Out:
#           count         mean         std     min       25%     50%       75%  \
# mpg       398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
# cyl       398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp      398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# wt        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc       398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr        398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# origin    398.0     1.572864    0.802055     1.0     1.000     1.0     2.000
# car_type  398.0     0.530151    0.499718     0.0     0.000     1.0     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# wt        5140.0
# acc         24.8
# yr          82.0
# origin       3.0
# car_type     1.0

# %%
Data.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# 3  16.0    8  304.0  150  3433  12.0  70       1         0
# 4  17.0    8  302.0  140  3449  10.5  70       1         0
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
# mpg         398 non-null float64
# cyl         398 non-null int64
# disp        398 non-null float64
# hp          398 non-null object
# wt          398 non-null int64
# acc         398 non-null float64
# yr          398 non-null int64
# origin      398 non-null int64
# car_type    398 non-null int64
# car_name    398 non-null object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 31.2+ KB

# %%
Data['hp'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
temp=pd.DataFrame(Data.hp.str.isdigit())

# %%
temp[temp['hp']==False]
# Out:
#         hp
# 32   False
# 126  False
# 330  False
# 336  False
# 354  False
# 374  False

# %%
Data.hp.replace('?',np.NaN,inplace=True)

# %%
Data.hp.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', nan, '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
Data[Data.isnull().any(axis=1)]
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 32   25.0    4   98.0  NaN  2046  19.0  71       1         1
# 126  21.0    6  200.0  NaN  2875  17.0  74       1         0
# 330  40.9    4   85.0  NaN  1835  17.3  80       2         1
# 336  23.6    4  140.0  NaN  2905  14.3  80       1         1
# 354  34.5    4  100.0  NaN  2320  15.8  81       2         1
# 374  23.0    4  151.0  NaN  3035  20.5  82       1         1
#
#                  car_name
# 32             ford pinto
# 126         ford maverick
# 330  renault lecar deluxe
# 336    ford mustang cobra
# 354           renault 18i
# 374        amc concord dl

# %%
Data.hp=Data.hp.fillna(Data['hp'].median())

# %%
Data.hp.dtype
# Out:
# dtype('O')

# %%
Data.hp=Data.hp.astype('float64')

# %%
Data.hp.dtype
# Out:
# dtype('float64')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
# mpg         398 non-null float64
# cyl         398 non-null int64
# disp        398 non-null float64
# hp          398 non-null float64
# wt          398 non-null int64
# acc         398 non-null float64
# yr          398 non-null int64
# origin      398 non-null int64
# car_type    398 non-null int64
# car_name    398 non-null object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 31.2+ KB

# %%
Data=Data.drop('car_name',axis=1)

# %%
Data.corr()
# Out:
#                mpg       cyl      disp        hp        wt       acc  \
# mpg       1.000000 -0.775396 -0.804203 -0.773453 -0.831741  0.420289
# cyl      -0.775396  1.000000  0.950721  0.841284  0.896017 -0.505419
# disp     -0.804203  0.950721  1.000000  0.895778  0.932824 -0.543684
# hp       -0.773453  0.841284  0.895778  1.000000  0.862442 -0.686590
# wt       -0.831741  0.896017  0.932824  0.862442  1.000000 -0.417457
# acc       0.420289 -0.505419 -0.543684 -0.686590 -0.417457  1.000000
# yr        0.579267 -0.348746 -0.370164 -0.413733 -0.306564  0.288137
# origin    0.563450 -0.562543 -0.609409 -0.452096 -0.581024  0.205873
# car_type  0.759207 -0.912577 -0.855141 -0.701399 -0.815445  0.385187
#
#                 yr    origin  car_type
# mpg       0.579267  0.563450  0.759207
# cyl      -0.348746 -0.562543 -0.912577
# disp     -0.370164 -0.609409 -0.855141
# hp       -0.413733 -0.452096 -0.701399
# wt       -0.306564 -0.581024 -0.815445
# acc       0.288137  0.205873  0.385187
# yr        1.000000  0.180662  0.305194
# origin    0.180662  1.000000  0.572691
# car_type  0.305194  0.572691  1.000000

# %%
sns.pairplot(Data,diag_kind='kde')
# Out:
# C:\Users\shaik khaja vali\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Data.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'wt', 'acc', 'yr', 'origin', 'car_type'], dtype='object')

# %%
import statsmodels.formula.api as smf
m1=smf.ols('mpg~cyl+disp+hp+wt+acc+yr+origin+car_type',Data).fit()

# %%
m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     255.3
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):          1.15e-149
# Time:                        12:47:01   Log-Likelihood:                -1017.9
# No. Observations:                 398   AIC:                             2054.
# Df Residuals:                     389   BIC:                             2090.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -27.0537      4.559     -5.934      0.000     -36.017     -18.090
# cyl            1.2555      0.392      3.206      0.001       0.485       2.026
# disp           0.0183      0.007      2.566      0.011       0.004       0.032
# hp            -0.0329      0.013     -2.512      0.012      -0.059      -0.007
# wt            -0.0063      0.001    -10.228      0.000      -0.007      -0.005
# acc            0.0907      0.092      0.988      0.324      -0.090       0.271
# yr             0.7362      0.048     15.374      0.000       0.642       0.830
# origin         1.1833      0.263      4.491      0.000       0.665       1.701
# car_type       5.6632      0.831      6.812      0.000       4.029       7.298
# ==============================================================================
# Omnibus:                       39.580   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.706
# Skew:                           0.609   Prob(JB):                     7.31e-16
# Kurtosis:                       4.649   Cond. No.                     8.94e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.94e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ###### heare the p value for Acc is higher that 0.05 then we it is not much significant in the linear model so we are droping acc

# %%
Data=Data.drop('acc',axis=1)

# %%
m1=smf.ols('mpg~cyl+disp+hp+wt+yr+origin+car_type',Data).fit()

# %%
m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     291.7
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):          1.06e-150
# Time:                        12:47:02   Log-Likelihood:                -1018.4
# No. Observations:                 398   AIC:                             2053.
# Df Residuals:                     390   BIC:                             2085.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -25.1969      4.154     -6.066      0.000     -33.363     -17.031
# cyl            1.2447      0.392      3.179      0.002       0.475       2.014
# disp           0.0175      0.007      2.471      0.014       0.004       0.031
# hp            -0.0406      0.011     -3.837      0.000      -0.061      -0.020
# wt            -0.0060      0.001    -11.041      0.000      -0.007      -0.005
# yr             0.7326      0.048     15.344      0.000       0.639       0.826
# origin         1.1802      0.263      4.480      0.000       0.662       1.698
# car_type       5.6728      0.831      6.824      0.000       4.039       7.307
# ==============================================================================
# Omnibus:                       43.753   Durbin-Watson:                   1.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.662
# Skew:                           0.648   Prob(JB):                     3.05e-18
# Kurtosis:                       4.784   Cond. No.                     8.15e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x=Data.drop('mpg',axis=1)
y=Data[['mpg']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()
LR.fit(X_train,Y_train)
mpg_pred=LR.predict(X_test)

# %%
LR.score(X_test,Y_test)# adjusted R2
# Out:
# 0.8561259796581131

# %%
from sklearn import metrics

# %%
rmse=np.sqrt(metrics.mean_squared_error(Y_test,mpg_pred))
rmse
# Out:
# 2.9149209976396118

# %%
LR.score(X_test,Y_test)
# Out:
# 0.8561259796581131

# %%
plt.plot(Y_test,mpg_pred,'*')

# %%
plt.plot(X_test['disp'],Y_test,'*')
plt.plot(X_test['disp'],mpg_pred,'+')

# %%
Data2= pd.read_csv("Advertising-1.csv",index_col=0)

# %%
sns.heatmap(Data2.corr(),annot=True)

# %%
sns.heatmap((Data2.corr())**2,annot=True) # R2

# %%
sns.pairplot(Data2)

# %%
model=smf.ols('Sales~TV+Radio+Newspaper',Data2).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           1.58e-96
# Time:                        13:00:55   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
